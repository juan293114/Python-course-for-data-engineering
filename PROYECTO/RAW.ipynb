# %%
import json
from pathlib import Path
import pandas as pd

# %%
df = (spark.read.format("csv")
.option("inferSchema", "true")
.option("delimiter", ";")
.option("header","true").load("/Volumes/workspace/raw/transacciones/superstore2.csv"))
display(df.limit(100))

# %%
print(df.select('Order ID').distinct().count())
print(df.count())
