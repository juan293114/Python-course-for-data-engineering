# %%
timeout = 0

try:
    
    dbutils.notebook.run("/Users/yennijimeno@gmail.com/Python-course-for-data-engineering/PROYECTO/A_Raw/Raw", timeout)
    dbutils.notebook.run("/Users/yennijimeno@gmail.com/Python-course-for-data-engineering/PROYECTO/B_Bronze/Bronze", timeout)
    dbutils.notebook.run("/Users/yennijimeno@gmail.com/Python-course-for-data-engineering/PROYECTO/C_Silver/Silver", timeout)
    dbutils.notebook.run("/Users/yennijimeno@gmail.com/Python-course-for-data-engineering/PROYECTO/D_Gold/Gold", timeout)



    print("Pipeline ejecutado correctamente")

except Exception as e:
       print("Error en la ejecucion del Pipeline")
       raise e
