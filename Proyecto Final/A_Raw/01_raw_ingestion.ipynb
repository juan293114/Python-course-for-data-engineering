# %%
df_orders = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("/Volumes/workspace/default/olist_raw/olist_orders_dataset.csv")

display(df_orders)

# %%
df_customers = spark.read.option("header", "true").option("inferSchema", "true") \
    .csv("/Volumes/workspace/default/olist_raw/olist_customers_dataset.csv")

df_order_items = spark.read.option("header", "true").option("inferSchema", "true") \
    .csv("/Volumes/workspace/default/olist_raw/olist_order_items_dataset.csv")

df_products = spark.read.option("header", "true").option("inferSchema", "true") \
    .csv("/Volumes/workspace/default/olist_raw/olist_products_dataset.csv")

df_payments = spark.read.option("header", "true").option("inferSchema", "true") \
    .csv("/Volumes/workspace/default/olist_raw/olist_order_payments_dataset.csv")

df_category = spark.read.option("header", "true").option("inferSchema", "true") \
    .csv("/Volumes/workspace/default/olist_raw/product_category_name_translation.csv")
