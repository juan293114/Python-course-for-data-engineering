# %%
spark.sql("DROP TABLE IF EXISTS workspace.gold.bridge_movie_actor")

df = spark.table("workspace.silver.movie_actors")

df.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("workspace.gold.bridge_movie_actor")
