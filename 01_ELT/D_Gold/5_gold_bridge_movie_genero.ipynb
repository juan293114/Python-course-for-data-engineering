# %%
spark.sql("DROP TABLE IF EXISTS workspace.gold.bridge_movie_genre")

df = spark.table("workspace.silver.movie_genres")

df.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("workspace.gold.bridge_movie_genre")
