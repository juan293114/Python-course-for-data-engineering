# %%
from pathlib import Path
import pandas as pd
from pyspark.sql.functions import col

# %%
ruta_raw = "/Volumes/workspace/raw/kaggle_adidas_us_sales/Adidas US Sales.csv"
raw_root = Path(ruta_raw)

# %%
# %sql
CREATE DATABASE IF NOT EXISTS workspace.bronze
COMMENT 'Capa Bronze: datos crudos procesados'

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS workspace.bronze.adidas_US_sales (
  sales_id LONG,
  retailer STRING,
  retailer_id LONG,
  invoice_date DATE,
  region STRING,
  state STRING,
  city STRING,
  product STRING,
  price_per_unit INT,
  units_sold INT,
  total_sales INT,
  operating_profit INT,
  sales_method STRING
)
""")

# %%
df = pd.read_csv(ruta_raw , index_col=False)
df_spark = spark.createDataFrame(df)
df_spark = df_spark \
    .withColumn("sales_id", col("sales_id").cast("long")) \
    .withColumn("retailer", col("retailer").cast("string")) \
    .withColumn("retailer_id", col("retailer_id").cast("long")) \
    .withColumn("invoice_date", col("invoice_date").cast("date")) \
    .withColumn("region", col("region").cast("string")) \
    .withColumn("state", col("state").cast("string")) \
    .withColumn("city", col("city").cast("string")) \
    .withColumn("product", col("product").cast("string")) \
    .withColumn("units_sold", col("units_sold").cast("long")) \
    .withColumn("price_per_unit", col("price_per_unit").cast("int")) \
    .withColumn("units_sold", col("units_sold").cast("int")) \
    .withColumn("total_sales", col("total_sales").cast("int")) \
    .withColumn("operating_profit", col("operating_profit").cast("int")) \
    .withColumn("sales_method", col("sales_method").cast("string"))

# %%
# Usamos overwrite para reemplazar completamente los datos existentes
df_spark.write.format("delta") \
    .mode("overwrite") \
    .option("mergeSchema", "true") \
    .saveAsTable("workspace.bronze.adidas_US_sales")
