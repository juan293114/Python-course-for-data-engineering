# %%
# Notebook Orquestador
print("Iniciando Pipeline de Datos...")
dbutils.notebook.run("./01_Extract_Raw", 0)
dbutils.notebook.run("./02_Load_Bronze", 0)
dbutils.notebook.run("./03_Transform_Silver", 0)
dbutils.notebook.run("./04_Transform_Gold", 0)
print("Pipeline ejecutado exitosamente.")
